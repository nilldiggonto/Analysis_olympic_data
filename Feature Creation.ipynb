# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette='rainbow')

# %%
#data
data = pd.read_csv('files/summer.csv')
data_1996 = pd.read_csv('data_1996.csv',index_col='Country')
data_1976 = pd.read_csv('data_1976.csv',index_col='Country')

# %%
data.head(1)
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
#
#             Event Medal
# 0  100M Freestyle  Gold

# %%
data_1976.head(1)
# Out:
#          Gold  Silver  Bronze
# Country
# URS        49      41      35

# %%
data_1996.head(1)
# Out:
#          Gold  Silver  Bronze
# Country
# USA        44      32      25

# %%
###Time to find out all the events to determine which medal belongs to which event
# But first to findout if the event is only for male or female or mixed

# %%
data['Gender'].value_counts()
# Out:
# Men      22746
# Women     8419
# Name: Gender, dtype: int64

# %%
data['Event_type'] = data['Gender']

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_type
# 0              100M Freestyle    Gold        Men
# 1              100M Freestyle  Silver        Men
# 2  100M Freestyle For Sailors  Bronze        Men
# 3  100M Freestyle For Sailors    Gold        Men
# 4  100M Freestyle For Sailors  Silver        Men

# %%
data['Event'].str.lower().str.contains('mixed').sum()
# Out:
# 38

# %%
 data['Event'].value_counts()
# Out:
# Football                          1497
# Hockey                            1422
# Team Competition                  1147
# Basketball                        1012
# Handball                           973
#                                   ...
# Moving Bird Target, 28M              2
# 47.63 - 52.16KG (Bantamweight)       2
# - 47.63KG (Flyweight)                2
# 65.77 - 71.67KG (Middleweight)       2
# Open Class A                         1
# Name: Event, Length: 666, dtype: int64

# %%
#now to more details analysis about the events where male and female participate #google search can be useful

# %%
data['Event'].str.lower().str.contains('pairs').sum()
# Out:
# 12

# %%
data['Sport'].str.lower().str.contains('equestrian').sum()
# Out:
# 939

# %%
#all sailing events before 1988 have been mixed events

# %%
( (data['Sport'].str.lower().str.contains('sailing')) & (data['Year']<1988) ).sum()
# Out:
# 755

# %%
# assigning them in a variable

# %%
m1 = data['Event'].str.lower().str.contains('mixed')
m2 = data['Event'].str.lower().str.contains('pairs')
m3 = data['Sport'].str.lower().str.contains('equestrian') 
m4 = ( (data['Sport'].str.lower().str.contains('sailing')) & (data['Year']<1988) )

# %%
#Given value to "x" where event type is mixed

# %%
data.loc[ m1 | m2 | m3 | m4,'Event_type'] ='Both'

# %%
data.Event_type.value_counts()
# Out:
# Men      21229
# Women     8192
# Both      1744
# Name: Event_type, dtype: int64

# %%
#for mixed event # needed to use extensive google search

# %%
#badminton mixed event

# %%
badminton_m = [21773, 21782, 21776, 21785, 21770, 21779, 23703, 23712, 23706, 23715, 23709, 23700, 25720, 25729, 25723, 25732, 25726, 25717, 27727, 27736, 27730, 27739, 27724, 27733, 29784, 29785, 29786, 29787, 29788, 29789]

# %%
data.loc[badminton_m,'Event_type']= 'Both'

# %%
data['Event_type'].value_counts()
# Out:
# Men      21214
# Women     8177
# Both      1774
# Name: Event_type, dtype: int64

# %%
#### all unique events and counting medal

# %%
medal_groupby = data.groupby(['Year','Sport','Discipline','Event','Event_type'])

# %%
medal_groupby['Medal'].transform('count')
# Out:
# 0        2
# 1        2
# 2        3
# 3        3
# 4        3
#         ..
# 31160    4
# 31161    4
# 31162    4
# 31163    4
# 31164    4
# Name: Medal, Length: 31165, dtype: int64

# %%
data['Event_Medal'] = medal_groupby['Medal'].transform('count')

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_type  Event_Medal
# 0              100M Freestyle    Gold        Men            2
# 1              100M Freestyle  Silver        Men            2
# 2  100M Freestyle For Sailors  Bronze        Men            3
# 3  100M Freestyle For Sailors    Gold        Men            3
# 4  100M Freestyle For Sailors  Silver        Men            3

# %%
data['Event_Medal'].value_counts().sort_index()
# Out:
# 1         5
# 2        48
# 3      9234
# 4      1688
# 5        50
#        ...
# 73       73
# 74       74
# 76       76
# 82       82
# 116     116
# Name: Event_Medal, Length: 66, dtype: int64

# %%
data.loc[data['Event_Medal']==5]
# Out:
#        Year         City       Sport   Discipline                     Athlete  \
# 1273   1908       London   Athletics    Athletics     ARCHIBALD, Edward Blake
# 1274   1908       London   Athletics    Athletics     JACOBS, Charles Sherman
# 1275   1908       London   Athletics    Athletics           SÖDERSTRÖM, Bruno
# 1276   1908       London   Athletics    Athletics        COOKE, Edward Tiffin
# 1277   1908       London   Athletics    Athletics    GILBERT, Alfred Carleten
# 7770   1948       London  Gymnastics  Artistic G.     MOGYOROSI-KLENCS, Janos
# 7771   1948       London  Gymnastics  Artistic G.              PATAKI, Ferenc
# 7772   1948       London  Gymnastics  Artistic G.               SOTORNIK, Leo
# 7773   1948       London  Gymnastics  Artistic G.    AALTONEN, Paavo Johannes
# 7774   1948       London  Gymnastics  Artistic G.          ROVE, Olavi Antero
# 15748  1980       Moscow  Equestrian     Eventing                     PINTSET
# ...

# %%
#Event_medal works as there are 5 sport as 'Athletics' now to group a team event

# %%
data['Team'] = pd.Series(np.where(data['Event_Medal']>5,'Yes','No'))

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_type  Event_Medal Team
# 0              100M Freestyle    Gold        Men            2   No
# 1              100M Freestyle  Silver        Men            2   No
# 2  100M Freestyle For Sailors  Bronze        Men            3   No
# 3  100M Freestyle For Sailors    Gold        Men            3   No
# 4  100M Freestyle For Sailors  Silver        Men            3   No

# %%
data['Team'].value_counts()
# Out:
# Yes    20140
# No     11025
# Name: Team, dtype: int64

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_type  Event_Medal Team
# 0              100M Freestyle    Gold        Men            2   No
# 1              100M Freestyle  Silver        Men            2   No
# 2  100M Freestyle For Sailors  Bronze        Men            3   No
# 3  100M Freestyle For Sailors    Gold        Men            3   No
# 4  100M Freestyle For Sailors  Silver        Men            3   No

# %%
data.to_csv('summer_clean.csv',index=False)

# %%
data2 = pd.read_csv('summer_clean.csv')

# %%
data2.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_type  Event_Medal Team
# 0              100M Freestyle    Gold        Men            2   No
# 1              100M Freestyle  Silver        Men            2   No
# 2  100M Freestyle For Sailors  Bronze        Men            3   No
# 3  100M Freestyle For Sailors    Gold        Men            3   No
# 4  100M Freestyle For Sailors  Silver        Men            3   No
